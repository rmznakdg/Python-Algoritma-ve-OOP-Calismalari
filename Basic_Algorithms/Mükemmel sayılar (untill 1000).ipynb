# %%
mukemmel = []
for i in range(1,1001):
    toplam = 0
    for x in range(1,i):
        if i%x==0:
            toplam+=x
    if toplam == i:
        mukemmel.append(i)
print(mukemmel)
# Out:
# [6, 28, 496]

# %%
print(mukemmelSayilar())
# Out:
# []
# None
