# %%
def tamBolenleriBulma(sayi):
    tamBolenler = []
    i = 1
    while i<=sayi:
        if sayi % i == 0:
            tamBolenler.append(i)
            i+=1
        else:
            i+=1
    print(tamBolenler)

# %%
tamBolenleriBulma(8)
# Out:
# [1, 2, 4, 8]
