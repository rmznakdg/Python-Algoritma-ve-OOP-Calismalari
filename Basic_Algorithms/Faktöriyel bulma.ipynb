# %%
sayi = int(input("Bir sayı giriniz:"))
faktöryel = 1
for i in range(1,sayi+1):
    faktöryel*=i
print(f"{sayi}!={faktöryel}")
# Out:
# Bir sayı giriniz: 0
# 0!=1

# %%
print(*range(5))
# Out:
# 0 1 2 3 4
